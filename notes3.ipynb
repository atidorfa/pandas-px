# %%
people = {
    "first": ["Gonzalo", "Jane", "Joe"],
    "last": ["Rivero Baud", "Doe", "Doe"],
    "email": ["riverobaug@gmail.com", 'janedoe@email.com', "johndoe@email.com"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#      first         last                 email
# 0  Gonzalo  Rivero Baud  riverobaug@gmail.com
# 1     Jane          Doe     janedoe@email.com
# 2      Joe          Doe     johndoe@email.com

# %%
df['email']
# Out:
# 0    riverobaug@gmail.com
# 1       janedoe@email.com
# 2       johndoe@email.com
# Name: email, dtype: object

# %%
df.set_index('email', inplace=True)

# %%
df
# Out:
#                         first         last
# email
# riverobaug@gmail.com  Gonzalo  Rivero Baud
# janedoe@email.com        Jane          Doe
# johndoe@email.com         Joe          Doe

# %%
df.index
# Out:
# Index(['riverobaug@gmail.com', 'janedoe@email.com', 'johndoe@email.com'], dtype='object', name='email')

# %%
df.loc['janedoe@email.com']
# Out:
# first    Jane
# last      Doe
# Name: janedoe@email.com, dtype: object

# %%
df.loc['janedoe@email.com', 'last']
# Out:
# 'Doe'

# %%
df.iloc[0]
# Out:
# first        Gonzalo
# last     Rivero Baud
# Name: riverobaug@gmail.com, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                   email    first         last
# 0  riverobaug@gmail.com  Gonzalo  Rivero Baud
# 1     janedoe@email.com     Jane          Doe
# 2     johndoe@email.com      Joe          Doe

# %%
df2 = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')

# %%
df2.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %%
schema_df2 = pd.read_csv('data/survey_results_schema.csv', index_col = 'qname')

# %%
schema_df2
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# ...

# %%
schema_df2.loc['Ethnicity']
# Out:
# qid                                                      QID126
# question      Which of the following describe you, if any? P...
# force_resp                                                False
# type                                                         MC
# selector                                                   MAVR
# Name: Ethnicity, dtype: object

# %%
schema_df2.loc['Ethnicity', 'question']
# Out:
# 'Which of the following describe you, if any? Please check all that apply.'

# %%
schema_df2.sort_index(ascending=True)
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# ...
